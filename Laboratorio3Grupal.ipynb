# %% [markdown]
# <a href="https://colab.research.google.com/github/danidb29/Laboratorios-AnalisisDatos/blob/main/Laboratorio3Grupal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

students = [('Ana', 23, 'San Jose', 'A'),
            ('Esteban', 22, 'Heredia', 'B'),
            ('Juan', 22, 'Cartago', 'A'),
            ('Karla', 22, 'Limón', 'A'),
            ('Ernesto', 21, 'Heredia', 'B')
            ]

df = pd.DataFrame(students, columns = ['Nombre', 'Edad', 'Ciudad', 'Seccion'])
df
# Out:
#     Nombre  Edad    Ciudad Seccion
# 0      Ana    23  San Jose       A
# 1  Esteban    22   Heredia       B
# 2     Juan    22   Cartago       A
# 3    Karla    22     Limón       A
# 4  Ernesto    21   Heredia       B

# %%
import pandas as pd

def getIndexes (dfObj, value):
  listOfPos = []
  result = dfObj.isin([value])
  seriesObj = result.any()
  columnNames = list (seriesObj [seriesObj ==True].index)

  for col in columnNames:
    rows = list(result[col] [result[col] == True].index)
    for row in rows:
      listOfPos.append((row, col))

  return listOfPos

listOfPositions = getIndexes (df, 'A')

print('Index positions of 22 in Dataframe : ')

for i in range (len (listOfPositions)):
  print(listOfPositions [i])
# Out:
# Index positions of 22 in Dataframe :
# (0, 'Seccion')
# (2, 'Seccion')
# (3, 'Seccion')

# %%
csv = pd.read_csv('/content/top50MusicFrom2010-2019.csv')

dataSpotify = pd.DataFrame(csv)

dataSpotify
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#     the genre of the track  year  Beats.Per.Minute -The tempo of the song  \
# ...

# %%
listOfPositions = getIndexes (dataSpotify, 'dance pop')

print('Index positions of dance pop in Dataframe : ')

for i in range (len (listOfPositions)):
  print(listOfPositions [i])
# Out:
# Index positions of dance pop in Dataframe :
# (2, 'the genre of the track')
# (3, 'the genre of the track')
# (6, 'the genre of the track')
# (7, 'the genre of the track')
# (10, 'the genre of the track')
# (12, 'the genre of the track')
# (13, 'the genre of the track')
# (14, 'the genre of the track')
# (16, 'the genre of the track')
# (17, 'the genre of the track')
# (18, 'the genre of the track')
# (19, 'the genre of the track')
# (20, 'the genre of the track')
# (22, 'the genre of the track')
# (24, 'the genre of the track')
# (26, 'the genre of the track')
# (27, 'the genre of the track')
# (28, 'the genre of the track')
# (29, 'the genre of the track')
# (30, 'the genre of the track')
# (31, 'the genre of the track')
# (32, 'the genre of the track')
# (33, 'the genre of the track')
# (35, 'the genre of the track')
# (36, 'the genre of the track')
# (38, 'the genre of the track')
# (40, 'the genre of the track')
# (44, 'the genre of the track')
# (45, 'the genre of the track')
# ...

# %%
listOfPositions = getIndexes (dataSpotify, 2015)

print('Index positions of 2015 in Dataframe : ')

for i in range (len (listOfPositions)):
  print(listOfPositions [i])
# Out:
# Index positions of Bad Bunny in Dataframe :
# (268, 'year')
# (269, 'year')
# (270, 'year')
# (271, 'year')
# (272, 'year')
# (273, 'year')
# (274, 'year')
# (275, 'year')
# (276, 'year')
# (277, 'year')
# (278, 'year')
# (279, 'year')
# (280, 'year')
# (281, 'year')
# (282, 'year')
# (283, 'year')
# (284, 'year')
# (285, 'year')
# (286, 'year')
# (287, 'year')
# (288, 'year')
# (289, 'year')
# (290, 'year')
# (291, 'year')
# (292, 'year')
# (293, 'year')
# (294, 'year')
# (295, 'year')
# (296, 'year')
# (297, 'year')
# (298, 'year')
# (299, 'year')
# (300, 'year')
# (301, 'year')
# (302, 'year')
# (303, 'year')
# (304, 'year')
# (305, 'year')
# (306, 'year')
# (307, 'year')
# (308, 'year')
# (309, 'year')
# (310, 'year')
# (311, 'year')
# (312, 'year')
# (313, 'year')
# (314, 'year')
# (315, 'year')
# (316, 'year')
# (317, 'year')
# (318, 'year')
# (319, 'year')
# (320, 'year')
# (321, 'year')
# (322, 'year')
# (323, 'year')
# (324, 'year')
# (325, 'year')
# (326, 'year')
# ...

# %% [markdown]
# Estudiantes:
# Abraham Quesada Mora,
# Daniel Delgado Bernini,
# Adrián Solís Matamoros.
