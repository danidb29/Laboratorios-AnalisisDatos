# %% [markdown]
# <a href="https://colab.research.google.com/github/danidb29/Laboratorios-AnalisisDatos/blob/main/Laboratorio5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium

# %%
from folium.plugins import minimap;

# %%
casa = folium.Map(location = (9.998637, -84.134019))
casa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import MiniMap
from branca.element import Figure

popuptext = '<b>Casa Mia</b>'

my_map = folium.Map(location=[9.998637, -84.1340190], zoom_start=16, tiles='stamenterrain')

folium.Marker(location=[9.998637, -84.134019],popup=popuptext, icon = folium.Icon(color='orange',icon='ok-sign')).add_to(my_map)
folium.Circle(location=[9.998637, -84.134019], color='purple', weigth = 6, fill_color = 'red', fill_opacity=0.5, tooltip='Casa Berni').add_to(my_map)

folium.Marker(location=[9.969834341304288, -84.12906189784971],popup=popuptext, icon = folium.Icon(color='red',icon='ok-sign')).add_to(my_map)
folium.Circle(location=[9.969834341304288, -84.12906189784971], color='purple', weigth = 6, fill_color = 'purple', fill_opacity=0.5, tooltip='Campus Benjamin').add_to(my_map)

folium.Marker(location=[9.998951298925691, -84.11148205032794],popup=popuptext, icon = folium.Icon(color='yellow',icon='ok-sign')).add_to(my_map)
folium.Circle(location=[9.998858596353065, -84.11147159117866], color='purple', weigth = 6, fill_color = 'purple', fill_opacity=0.5, tooltip='Sede Central').add_to(my_map)

folium.Marker(location=[10.617717710583479, -85.45136438662837],popup=popuptext, icon = folium.Icon(color='black',icon='ok-sign')).add_to(my_map)
folium.Circle(location=[10.617717710583479, -85.45136438662837], color='purple', weigth = 6, fill_color = 'purple', fill_opacity=0.5, tooltip='Liberia').add_to(my_map)

folium.Marker(location=[9.390600049149615, -83.69411680377786],popup=popuptext, icon = folium.Icon(color='green',icon='ok-sign')).add_to(my_map)
folium.Circle(location=[9.390600049149615, -83.69411680377786], color='purple', weigth = 6, fill_color = 'purple', fill_opacity=0.5, tooltip='Perez').add_to(my_map)

folium.Marker(location=[10.019966268445284, -84.19702535969834],popup=popuptext, icon = folium.Icon(color='blue',icon='ok-sign')).add_to(my_map)
folium.Circle(location=[10.019966268445284, -84.19702535969834], color='purple', weigth = 6, fill_color = 'purple', fill_opacity=0.5, tooltip='Alajuela').add_to(my_map)

minimap = MiniMap(tile_layer='stamenterrain', position='bottomright')
my_map.add_child(minimap)
# Out:
# <ipython-input-6-2cda506818f8>:14: UserWarning: color argument of Icon should be one of: {'blue', 'black', 'gray', 'lightblue', 'orange', 'beige', 'lightred', 'green', 'darkpurple', 'purple', 'cadetblue', 'lightgreen', 'white', 'darkgreen', 'darkblue', 'pink', 'darkred', 'lightgray', 'red'}.
#   folium.Marker(location=[9.998951298925691, -84.11148205032794],popup=popuptext, icon = folium.Icon(color='yellow',icon='ok-sign')).add_to(my_map)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...
